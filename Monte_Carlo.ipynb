# %% [markdown]
# <a href="https://colab.research.google.com/github/Griffin-Jordan/StormStocks/blob/main/Monte_Carlo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
aapl_data = pd.read_csv("/content/AAPL.csv")

# %%
aapl_data
# Out:
#              Date        Open        High         Low       Close   Adj Close  \
# 0      1980-12-12    0.128348    0.128906    0.128348    0.128348    0.099192
# 1      1980-12-15    0.122210    0.122210    0.121652    0.121652    0.094017
# 2      1980-12-16    0.113281    0.113281    0.112723    0.112723    0.087117
# 3      1980-12-17    0.115513    0.116071    0.115513    0.115513    0.089273
# 4      1980-12-18    0.118862    0.119420    0.118862    0.118862    0.091861
# ...           ...         ...         ...         ...         ...         ...
# 10878  2024-02-07  190.639999  191.050003  188.610001  189.410004  189.168625
# 10879  2024-02-08  189.389999  189.539993  187.350006  188.320007  188.080017
# 10880  2024-02-09  188.649994  189.990005  188.000000  188.850006  188.850006
# 10881  2024-02-12  188.419998  188.669998  186.789993  187.149994  187.149994
# 10882  2024-02-13  185.770004  186.210007  183.509995  185.039993  185.039993
#
#           Volume
# ...

# %%
aapl_data = pd.DataFrame(aapl_data)
aapl_data["Date"] = pd.to_datetime(aapl_data["Date"])

# %%
aapl_data["DailyReturn"] = aapl_data['Close'] - aapl_data['Open'] / aapl_data['Open']

# %%
aapl_data["DailyReturn"]
# Out:
# 0         -0.871652
# 1         -0.878348
# 2         -0.887277
# 3         -0.884487
# 4         -0.881138
#             ...
# 10878    188.410004
# 10879    187.320007
# 10880    187.850006
# 10881    186.149994
# 10882    184.039993
# Name: DailyReturn, Length: 10883, dtype: float64
